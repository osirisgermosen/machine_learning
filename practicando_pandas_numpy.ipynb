# %%
import pandas as pd

# %%
orders = pd.read_csv('../Curso_IA/Amazon.csv')

# %%
orders.head(4)
# Out:
#       OrderID   OrderDate  CustomerID   CustomerName ProductID  \
# 0  ORD0000001  2023-01-31  CUST001504  Vihaan Sharma    P00014
# 1  ORD0000002  2023-12-30  CUST000178    Pooja Kumar    P00040
# 2  ORD0000003  2022-05-10  CUST047516    Sneha Singh    P00044
# 3  ORD0000004  2023-07-18  CUST030059   Vihaan Reddy    P00041
#
#            ProductName        Category       Brand  Quantity  UnitPrice  \
# 0           Drone Mini           Books   BrightLux         3     106.59
# 1           Microphone  Home & Kitchen  UrbanStyle         1     251.37
# 2  Power Bank 20000mAh        Clothing  UrbanStyle         3      35.03
# 3       Webcam Full HD  Home & Kitchen      Zenith         5      33.58
#
#    Discount    Tax  ShippingCost  TotalAmount     PaymentMethod OrderStatus  \
# 0      0.00   0.00          0.09       319.86        Debit Card   Delivered
# 1      0.05  19.10          1.74       259.64        Amazon Pay   Delivered
# ...

# %%
orders.tail(4)
# Out:
#           OrderID   OrderDate  CustomerID   CustomerName ProductID  \
# 99996  ORD0099997  2021-11-24  CUST031254  Sunita Kapoor    P00046
# 99997  ORD0099998  2023-04-29  CUST012579     Aman Gupta    P00030
# 99998  ORD0099999  2021-11-01  CUST026243   Simran Gupta    P00046
# 99999  ORD0100000  2021-12-04  CUST029492   Sunita Reddy    P00019
#
#          ProductName           Category      Brand  Quantity  UnitPrice  \
# 99996    Car Charger  Sports & Outdoors       Apex         5     449.30
# 99997    Dress Shirt  Sports & Outdoors  BrightLux         4     232.40
# 99998    Car Charger  Sports & Outdoors   HomeEase         1     294.05
# 99999  LED Desk Lamp     Home & Kitchen   CoreTech         5     166.70
#
#        Discount     Tax  ShippingCost  TotalAmount     PaymentMethod  \
# 99996      0.00  179.72          6.07      2432.29       Credit Card
# 99997      0.00   74.37         12.43      1016.40  Cash on Delivery
# ...

# %%
orders.shape
# Out:
# (100000, 20)

# %% [raw]
# orders.index

# %%
orders.columns
# Out:
# Index(['OrderID', 'OrderDate', 'CustomerID', 'CustomerName', 'ProductID',
#        'ProductName', 'Category', 'Brand', 'Quantity', 'UnitPrice', 'Discount',
#        'Tax', 'ShippingCost', 'TotalAmount', 'PaymentMethod', 'OrderStatus',
#        'City', 'State', 'Country', 'SellerID', 'DiscountExtra', 'Incorrecta'],
#       dtype='object')

# %%
orders.columns[1:4]
# Out:
# Index(['OrderDate', 'CustomerID', 'CustomerName'], dtype='object')

# %%
orders[orders.columns[8:14]]
# Out:
#        Quantity  UnitPrice  Discount     Tax  ShippingCost  TotalAmount
# 0             3     106.59      0.00    0.00          0.09       319.86
# 1             1     251.37      0.05   19.10          1.74       259.64
# 2             3      35.03      0.10    7.57          5.91       108.06
# 3             5      33.58      0.15   11.42          5.53       159.66
# 4             2     515.64      0.25   38.67          9.23       821.36
# ...         ...        ...       ...     ...           ...          ...
# 99995         2     492.34      0.00   78.77          2.75      1066.20
# 99996         5     449.30      0.00  179.72          6.07      2432.29
# 99997         4     232.40      0.00   74.37         12.43      1016.40
# 99998         1     294.05      0.00   23.52         13.09       330.66
# 99999         5     166.70      0.05   63.35          3.34       858.52
#
# [100000 rows x 6 columns]

# %%
orders.dtypes
# Out:
# OrderID           object
# OrderDate         object
# CustomerID        object
# CustomerName      object
# ProductID         object
# ProductName       object
# Category          object
# Brand             object
# Quantity           int64
# UnitPrice        float64
# Discount         float64
# Tax              float64
# ShippingCost     float64
# TotalAmount      float64
# PaymentMethod     object
# OrderStatus       object
# City              object
# State             object
# Country           object
# SellerID          object
# dtype: object

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 20 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   OrderID        100000 non-null  object
#  1   OrderDate      100000 non-null  object
#  2   CustomerID     100000 non-null  object
#  3   CustomerName   100000 non-null  object
#  4   ProductID      100000 non-null  object
#  5   ProductName    100000 non-null  object
#  6   Category       100000 non-null  object
#  7   Brand          100000 non-null  object
#  8   Quantity       100000 non-null  int64
#  9   UnitPrice      100000 non-null  float64
#  10  Discount       100000 non-null  float64
#  11  Tax            100000 non-null  float64
#  12  ShippingCost   100000 non-null  float64
#  13  TotalAmount    100000 non-null  float64
#  14  PaymentMethod  100000 non-null  object
#  15  OrderStatus    100000 non-null  object
#  16  City           100000 non-null  object
# ...

# %%
orders.describe()
# Out:
#             Quantity      UnitPrice       Discount            Tax  \
# count  100000.000000  100000.000000  100000.000000  100000.000000
# mean        3.001400     302.905748       0.074226      68.468902
# std         1.413548     171.840797       0.082583      74.131180
# min         1.000000       5.000000       0.000000       0.000000
# 25%         2.000000     154.190000       0.000000      15.920000
# 50%         3.000000     303.070000       0.050000      45.250000
# 75%         4.000000     451.500000       0.100000      96.060000
# max         5.000000     599.990000       0.300000     538.460000
#
#         ShippingCost    TotalAmount
# count  100000.000000  100000.000000
# mean        7.406660     918.256479
# std         4.324057     724.508332
# min         0.000000       4.270000
# 25%         3.680000     340.890000
# 50%         7.300000     714.315000
# 75%        11.150000    1349.765000
# max        15.000000    3534.980000

# %%
orders.head(3)
# Out:
#       OrderID   OrderDate  CustomerID   CustomerName ProductID  \
# 0  ORD0000001  2023-01-31  CUST001504  Vihaan Sharma    P00014
# 1  ORD0000002  2023-12-30  CUST000178    Pooja Kumar    P00040
# 2  ORD0000003  2022-05-10  CUST047516    Sneha Singh    P00044
#
#            ProductName        Category       Brand  Quantity  UnitPrice  \
# 0           Drone Mini           Books   BrightLux         3     106.59
# 1           Microphone  Home & Kitchen  UrbanStyle         1     251.37
# 2  Power Bank 20000mAh        Clothing  UrbanStyle         3      35.03
#
#    Discount    Tax  ShippingCost  TotalAmount PaymentMethod OrderStatus  \
# 0      0.00   0.00          0.09       319.86    Debit Card   Delivered
# 1      0.05  19.10          1.74       259.64    Amazon Pay   Delivered
# 2      0.10   7.57          5.91       108.06    Debit Card   Delivered
#
#          City State        Country   SellerID
# 0  Washington    DC          India  SELL01967
# ...

# %%
orders['PaymentMethod'].value_counts()
# Out:
# PaymentMethod
# Credit Card         35038
# Debit Card          20024
# UPI                 15066
# Amazon Pay          15017
# Net Banking          9927
# Cash on Delivery     4928
# Name: count, dtype: int64

# %%
orders['State'].value_counts()
# Out:
# State
# TX    24896
# CA    19921
# NC     5110
# FL     5107
# WA     5039
# OH     5021
# DC     5021
# IL     5020
# PA     5014
# CO     4991
# IN     4970
# NY     4949
# AZ     4941
# Name: count, dtype: int64

# %%
orders.head(2)
# Out:
#       OrderID   OrderDate  CustomerID   CustomerName ProductID ProductName  \
# 0  ORD0000001  2023-01-31  CUST001504  Vihaan Sharma    P00014  Drone Mini
# 1  ORD0000002  2023-12-30  CUST000178    Pooja Kumar    P00040  Microphone
#
#          Category       Brand  Quantity  UnitPrice  Discount   Tax  \
# 0           Books   BrightLux         3     106.59      0.00   0.0
# 1  Home & Kitchen  UrbanStyle         1     251.37      0.05  19.1
#
#    ShippingCost  TotalAmount PaymentMethod OrderStatus        City State  \
# 0          0.09       319.86    Debit Card   Delivered  Washington    DC
# 1          1.74       259.64    Amazon Pay   Delivered  Fort Worth    TX
#
#          Country   SellerID
# 0          India  SELL01967
# 1  United States  SELL01298

# %%
orders['DiscountExtra'] = (orders['Quantity'] *  orders['UnitPrice']) * 0.75 / 100

# %%
orders.head(3)
# Out:
#       OrderID   OrderDate  CustomerID   CustomerName ProductID  \
# 0  ORD0000001  2023-01-31  CUST001504  Vihaan Sharma    P00014
# 1  ORD0000002  2023-12-30  CUST000178    Pooja Kumar    P00040
# 2  ORD0000003  2022-05-10  CUST047516    Sneha Singh    P00044
#
#            ProductName        Category       Brand  Quantity  UnitPrice  ...  \
# 0           Drone Mini           Books   BrightLux         3     106.59  ...
# 1           Microphone  Home & Kitchen  UrbanStyle         1     251.37  ...
# 2  Power Bank 20000mAh        Clothing  UrbanStyle         3      35.03  ...
#
#      Tax  ShippingCost  TotalAmount  PaymentMethod OrderStatus        City  \
# 0   0.00          0.09       319.86     Debit Card   Delivered  Washington
# 1  19.10          1.74       259.64     Amazon Pay   Delivered  Fort Worth
# 2   7.57          5.91       108.06     Debit Card   Delivered      Austin
#
#   State        Country   SellerID DiscountExtra
# 0    DC          India  SELL01967      2.398275
# ...

# %%
orders['UnitPrice'].sum()
# Out:
# np.float64(30290574.84)

# %%
orders['UnitPrice'].max()
# Out:
# np.float64(599.99)

# %%
orders['UnitPrice'].min()
# Out:
# np.float64(5.0)

# %%
orders.sort_values('TotalAmount').head(8)
# Out:
#           OrderID   OrderDate  CustomerID  CustomerName ProductID  \
# 86771  ORD0086772  2022-02-03  CUST043262   Aarav Singh    P00029
# 68176  ORD0068177  2020-03-29  CUST004688  Mohit Kapoor    P00039
# 4730   ORD0004731  2023-07-10  CUST043142   Karan Mehta    P00007
# 99805  ORD0099806  2024-03-29  CUST017538   Sneha Gupta    P00029
# 38172  ORD0038173  2022-06-18  CUST025567   Pooja Kumar    P00040
# 40270  ORD0040271  2021-12-04  CUST035371  Vihaan Patel    P00047
# 37279  ORD0037280  2021-04-01  CUST031790   Pooja Patel    P00001
# 36532  ORD0036533  2021-09-10  CUST030805  Anjali Patel    P00025
#
#                ProductName           Category     Brand  Quantity  UnitPrice  \
# 86771              T-Shirt  Sports & Outdoors   FitLife         1       5.57
# 68176       Graphic Tablet           Clothing    Zenith         1       5.26
# 4730   Mechanical Keyboard              Books    NexPro         1       6.25
# ...

# %%
orders.sort_values('TotalAmount', ascending=False).head(8)
# Out:
#           OrderID   OrderDate  CustomerID  CustomerName ProductID  \
# 48442  ORD0048443  2020-01-12  CUST010794  Anjali Patel    P00033
# 81886  ORD0081887  2020-09-26  CUST031626  Vivaan Joshi    P00048
# 4196   ORD0004197  2021-02-22  CUST022868   Kabir Gupta    P00029
# 1929   ORD0001930  2023-08-18  CUST031209   Pooja Patel    P00025
# 58204  ORD0058205  2021-10-19  CUST033287   Priya Gupta    P00031
# 46764  ORD0046765  2024-04-13  CUST044400  Priya Kapoor    P00034
# 40146  ORD0040147  2024-10-07  CUST001991   Pooja Mehta    P00002
# 20578  ORD0020579  2023-09-24  CUST016754  Sneha Sharma    P00015
#
#              ProductName           Category       Brand  Quantity  UnitPrice  \
# 48442      Puzzle 1000pc     Home & Kitchen  UrbanStyle         5     598.29
# 81886   Wireless Charger       Toys & Games    HomeEase         5     596.47
# 4196             T-Shirt     Home & Kitchen      Zenith         5     595.26
# ...

# %%
orders.sort_values('CustomerName', ascending=True, key=lambda x: x.str.lower())
# Out:
#           OrderID   OrderDate  CustomerID  CustomerName ProductID  \
# 19206  ORD0019207  2021-02-16  CUST021780   Aarav Gupta    P00005
# 18949  ORD0018950  2023-07-05  CUST026593   Aarav Gupta    P00040
# 22248  ORD0022249  2023-07-23  CUST039229   Aarav Gupta    P00025
# 63767  ORD0063768  2021-09-20  CUST030976   Aarav Gupta    P00022
# 45936  ORD0045937  2022-11-13  CUST014123   Aarav Gupta    P00019
# ...           ...         ...         ...           ...       ...
# 58480  ORD0058481  2022-08-15  CUST046251  Vivaan Verma    P00018
# 29252  ORD0029253  2022-12-19  CUST006224  Vivaan Verma    P00025
# 58774  ORD0058775  2023-01-14  CUST002835  Vivaan Verma    P00031
# 5117   ORD0005118  2022-07-12  CUST003649  Vivaan Verma    P00031
# 41539  ORD0041540  2023-02-04  CUST024900  Vivaan Verma    P00005
#
#           ProductName           Category       Brand  Quantity  UnitPrice  \
# 19206   Laptop Sleeve        Electronics    HomeEase         4      14.47
# ...

# %%
orders['Incorrecta'] = 70

# %%
orders
# Out:
#           OrderID   OrderDate  CustomerID   CustomerName ProductID  \
# 0      ORD0000001  2023-01-31  CUST001504  Vihaan Sharma    P00014
# 1      ORD0000002  2023-12-30  CUST000178    Pooja Kumar    P00040
# 2      ORD0000003  2022-05-10  CUST047516    Sneha Singh    P00044
# 3      ORD0000004  2023-07-18  CUST030059   Vihaan Reddy    P00041
# 4      ORD0000005  2023-02-04  CUST048677  Aditya Kapoor    P00029
# ...           ...         ...         ...            ...       ...
# 99995  ORD0099996  2023-03-07  CUST001356    Karan Joshi    P00047
# 99996  ORD0099997  2021-11-24  CUST031254  Sunita Kapoor    P00046
# 99997  ORD0099998  2023-04-29  CUST012579     Aman Gupta    P00030
# 99998  ORD0099999  2021-11-01  CUST026243   Simran Gupta    P00046
# 99999  ORD0100000  2021-12-04  CUST029492   Sunita Reddy    P00019
#
#                ProductName           Category       Brand  Quantity  \
# 0               Drone Mini              Books   BrightLux         3
# ...

# %%
orders.drop(columns=['Incorrecta'])
# Out:
#           OrderID   OrderDate  CustomerID   CustomerName ProductID  \
# 0      ORD0000001  2023-01-31  CUST001504  Vihaan Sharma    P00014
# 1      ORD0000002  2023-12-30  CUST000178    Pooja Kumar    P00040
# 2      ORD0000003  2022-05-10  CUST047516    Sneha Singh    P00044
# 3      ORD0000004  2023-07-18  CUST030059   Vihaan Reddy    P00041
# 4      ORD0000005  2023-02-04  CUST048677  Aditya Kapoor    P00029
# ...           ...         ...         ...            ...       ...
# 99995  ORD0099996  2023-03-07  CUST001356    Karan Joshi    P00047
# 99996  ORD0099997  2021-11-24  CUST031254  Sunita Kapoor    P00046
# 99997  ORD0099998  2023-04-29  CUST012579     Aman Gupta    P00030
# 99998  ORD0099999  2021-11-01  CUST026243   Simran Gupta    P00046
# 99999  ORD0100000  2021-12-04  CUST029492   Sunita Reddy    P00019
#
#                ProductName           Category       Brand  Quantity  \
# 0               Drone Mini              Books   BrightLux         3
# ...

# %%
orders = orders.drop(columns=['Incorrecta'])

# %%
orders.head(6)
# Out:
#       OrderID   OrderDate  CustomerID   CustomerName ProductID  \
# 0  ORD0000001  2023-01-31  CUST001504  Vihaan Sharma    P00014
# 1  ORD0000002  2023-12-30  CUST000178    Pooja Kumar    P00040
# 2  ORD0000003  2022-05-10  CUST047516    Sneha Singh    P00044
# 3  ORD0000004  2023-07-18  CUST030059   Vihaan Reddy    P00041
# 4  ORD0000005  2023-02-04  CUST048677  Aditya Kapoor    P00029
# 5  ORD0000006  2022-12-31  CUST042705   Karan Sharma    P00023
#
#            ProductName        Category       Brand  Quantity  UnitPrice  ...  \
# 0           Drone Mini           Books   BrightLux         3     106.59  ...
# 1           Microphone  Home & Kitchen  UrbanStyle         1     251.37  ...
# 2  Power Bank 20000mAh        Clothing  UrbanStyle         3      35.03  ...
# 3       Webcam Full HD  Home & Kitchen      Zenith         5      33.58  ...
# 4              T-Shirt        Clothing    KiddoFun         2     515.64  ...
# ...

# %%
orders_new = orders.head(100)

# %%
orders_new.to_csv('amazon_orders.csv', index=False)

# %%
orders['ProductName'].value_counts()
# Out:
# ProductName
# LED Desk Lamp                  2098
# Water Bottle                   2088
# Cookware Set                   2058
# Electric Kettle                2054
# Router                         2054
# Yoga Mat                       2041
# Board Game                     2039
# Memory Card 128GB              2039
# Smart Light Bulb               2036
# Mechanical Keyboard            2034
# Wireless Charger               2034
# Microphone                     2034
# Noise Cancelling Headphones    2031
# Portable SSD 1TB               2030
# Drone Mini                     2026
# Desk Organizer                 2026
# Action Camera                  2024
# Office Chair                   2018
# Vacuum Cleaner                 2017
# Instant Pot                    2016
# Webcam Full HD                 2013
# Gaming Mouse                   2010
# Wireless Earbuds               2008
# Air Fryer                      2007
# Dress Shirt                    2007
# ...
